# %% [markdown]
# <a href="https://colab.research.google.com/github/Sherryqilin/Assessment2_skills_group1/blob/Anna/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
articles=pd.read_csv("/content/drive/MyDrive/Group 1/articles.CDKN2A.csv")
articles
# Out:
#           PMID                                              Title  \
# 0     10551774  Transfection of an inducible p16/CDKN2A constr...
# 1     10595918  Malignant transformation of neurofibromas in n...
# 2     10620111  Genotype/phenotype and penetrance studies in m...
# 3     10630172  The genetics of hereditary melanoma and nevi. ...
# 4     10632344  Analysis of oncogene and tumor suppressor gene...
# ...        ...                                                ...
# 3409  38067238  Validation of a Gene Expression Approach for t...
# 3410  38070141  Has-miR-300-GADD45B promotes melanoma growth v...
# 3411  38079020  "De novo replication repair deficient glioblas...
# 3412  38091828  Dry and wet experiments reveal diagnostic clus...
# 3413  38095311  Compliant substrates mitigate the senescence a...
#
#                                                Abstract       ISSN  \
# 0     Recent studies have shown that methylation of ...  0888-8809
# ...

# %%
authors=pd.read_csv("/content/drive/MyDrive/Group 1/authors.CDKN2A.csv")
authors
# Out:
#            PMID  AuthorN AuthorForename AuthorLastname AuthorInitials  \
# 0      10551774        1            S J          Frost             SJ
# 1      10551774        2            D J        Simpson             DJ
# 2      10551774        3            R N        Clayton             RN
# 3      10551774        4            W E        Farrell             WE
# 4      10595918        1            G P        Nielsen             GP
# ...         ...      ...            ...            ...            ...
# 35763  38095311        4          Molly        Czachor              M
# 35764  38095311        5        Natalie        Schmier              N
# 35765  38095311        6         Claire        Pearson              C
# 35766  38095311        7        Chelsea         Bahney              C
# 35767  38095311        8         J Kent          Leach             JK
#
#                                        AuthorAffiliation
# 0      Centre for Cell and Molecular Medicine, School...
# ...

# %%
papers=pd.read_csv("/content/drive/MyDrive/Group 1/paper_counts.csv")
papers
# Out:
#      Year    Count
# 0    1799        1
# 1    1801        1
# 2    1802        1
# 3    1805        1
# 4    1866        1
# ..    ...      ...
# 138  2020  1132241
# 139  2021  1277048
# 140  2022  1324650
# 141  2023  1302390
# 142  2024    15611
#
# [143 rows x 2 columns]

# %%
recent_papers = papers[papers['Year'] >= (papers['Year'].max() - 4)]
recent_papers
# Out:
#      Year    Count
# 138  2020  1132241
# 139  2021  1277048
# 140  2022  1324650
# 141  2023  1302390
# 142  2024    15611

# %%
merged_data=pd.merge(authors,recent_papers,left_on='PMID',right_index=True)
merged_data.head()
# Out:
# Empty DataFrame
# Columns: [PMID, AuthorN, AuthorForename, AuthorLastname, AuthorInitials, AuthorAffiliation, Year, Count]
# Index: []

# %%
# Get unique full author names
unique_authors = merged_data.groupby(['AuthorForename', 'AuthorLastname']).size().reset_index().rename(columns={0:'count'})
unique_authors
# Out:
# Empty DataFrame
# Columns: [AuthorForename, AuthorLastname, count]
# Index: []

# %%
# Create and draw the graph with spring layout
import matplotlib.pyplot as plt

# Plot the collaboration frequency using a bar chart
plt.figure(figsize=(12, 6))
researcher_activity.plot(kind='bar')
plt.xlabel('Author Lastname')
plt.ylabel('Collaboration Frequency')
plt.title('Collaboration Network')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-3f98e946bb1e> in <cell line: 6>()
#       4 # Plot the collaboration frequency using a bar chart
#       5 plt.figure(figsize=(12, 6))
# ----> 6 researcher_activity.plot(kind='bar')
#       7 plt.xlabel('Author Lastname')
#       8 plt.ylabel('Collaboration Frequency')
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...
